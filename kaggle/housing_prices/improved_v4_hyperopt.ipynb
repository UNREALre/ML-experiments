# %% [markdown]
# # Попытка улучшить показатели лучшей реализации с ошибкой в ~12.93% RMSE
# Прошлый подход, где пытался сделать ансамбли - не состоялся. Он показал интересные результаты на простых линейных моделях, которые можно включать в ансамбль (стекингом, например) - и да, там результаты значительно лучше, чем у простой линейной модели. При попытке же использовать catboost  в бегинге или стекинге - ничего хорошего не было. Результаты улучшить не удалось. В общем-то потому, что catboost сам по себе уже ансамблевый подход реализует - это раз. В процессе интеграции в ансамбль - мы учим модель через тот же катбуст, но на какой-то усеченной пропорции данных и фич, как итог, получаем множество более слабых моделей, ансамбль усредняет все это дело и поэтому на выходе не можем получить ничего дельного.
#
# Сейчас мы попробуем вернуться к improved_realization, где мы получили показатели
# RMSE: 23271.3399
# R² (коэффициент детерминации): 0.9224
# Относительная ошибка (RMSE/mean): 12.93%
# И используя optuna для подбора гиперпараметров попробуем улучшить результаты.

# %%
from IPython.lib.deepreload import reload
from xgboost import train
# %load_ext autoreload
# %autoreload 2

import joblib
import numpy as np
import optuna
import pandas as pd

from catboost import CatBoostRegressor
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, root_mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, PowerTransformer, RobustScaler, QuantileTransformer, PolynomialFeatures, KBinsDiscretizer

# Вместо одного фиксированного разбиения на train/test используем стабильную стратегию кросс-валидации.
# Используем тут Cross-validation, потому что:
# 	•	нужно надёжно сравнить несколько разных моделей или гиперпараметров и понять, какая модель стабильнее и лучше в целом.
# 	•	хотим избежать случайных удач или провалов, связанных с конкретным разбиением на train/test.
# 	•	выбираем модель или гиперпараметры, которые потом будешь использовать для финального сабмишна на Kaggle.
# Делаем эту оценку, чтобы в дальнейших блокнотах-улучшениях сравнивать более корректно.
from sklearn.model_selection import KFold, cross_val_score, train_test_split

from utils.data_manager import DataManager
from utils.model_manager import ModelManager

# %% [markdown]
# ## 1. Загрузка данных

# %%
data_path = 'data/home-data-for-ml-course'
train_data = pd.read_csv(data_path + '/train.csv')
test_data = pd.read_csv(data_path + '/test.csv')

# %% [markdown]
# ## 2. Предобработка данных

# %%
dm = DataManager()

# %% [markdown]
# ### 2.1. Удаление ненужных столбцов

# %%
intuitively_bad_features = [
    'LotShape',  # Общая форма участка
    'LandContour',  # Рельеф участка
    'LotConfig',  # Конфигурация участка
    'LandSlope',  # Уклон участка
    'MiscFeature',
    'MiscVal',
]
bad_columns = dm.get_all_nan_cols(train_data)
bad_columns.append('Id')
bad_columns.extend(intuitively_bad_features)
bad_columns
# Out:
# ['Id',
#  'LotShape',
#  'LandContour',
#  'LotConfig',
#  'LandSlope',
#  'MiscFeature',
#  'MiscVal']

# %%
train_data = train_data.drop(columns=bad_columns)
train_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley Utilities  \
# 0          60       RL         65.0     8450   Pave   NaN    AllPub
# 1          20       RL         80.0     9600   Pave   NaN    AllPub
# 2          60       RL         68.0    11250   Pave   NaN    AllPub
# 3          70       RL         60.0     9550   Pave   NaN    AllPub
# 4          60       RL         84.0    14260   Pave   NaN    AllPub
#
#   Neighborhood Condition1 Condition2  ... 3SsnPorch ScreenPorch  PoolArea  \
# 0      CollgCr       Norm       Norm  ...         0           0         0
# 1      Veenker      Feedr       Norm  ...         0           0         0
# 2      CollgCr       Norm       Norm  ...         0           0         0
# 3      Crawfor       Norm       Norm  ...         0           0         0
# 4      NoRidge       Norm       Norm  ...         0           0         0
#
#    PoolQC  Fence  MoSold YrSold SaleType SaleCondition SalePrice
# 0     NaN    NaN       2   2008       WD        Normal    208500
# 1     NaN    NaN       5   2007       WD        Normal    181500
# 2     NaN    NaN       9   2008       WD        Normal    223500
# 3     NaN    NaN       2   2006       WD       Abnorml    140000
# 4     NaN    NaN      12   2008       WD        Normal    250000
#
# [5 rows x 74 columns]

# %%
X, y = dm.split_data_set_to_x_y(train_data, 'SalePrice')
print(X.shape, y.shape)
# Out:
# (1460, 73) (1460,)

# %% [markdown]
# ### 2.2. Обработка пропущенных значений и нормализация данных через ColumnTransformer и Pipeline

# %%
# Получение числовых колонок
numeric_columns = X.select_dtypes(include=['float64', 'int64']).columns

# Получение нечисловых колонок (всех остальных)
non_numeric_columns = X.select_dtypes(exclude=['float64', 'int64']).columns

numeric_columns, non_numeric_columns
# Out:
# (Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#         'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#         'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#         'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#         'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#         'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#         'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MoSold',
#         'YrSold'],
#        dtype='object'),
#  Index(['MSZoning', 'Street', 'Alley', 'Utilities', 'Neighborhood',
#         'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#         'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#         'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#         'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir',
#         'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
#         'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC',
#         'Fence', 'SaleType', 'SaleCondition'],
#        dtype='object'))

# %%
# Создаем preprocessor с разными трансформерами для разных типов данных
preprocessor = ColumnTransformer(
    transformers=[
        # Для числовых - импутация средним
        ('num', Pipeline([
            ('imputer', SimpleImputer(strategy='mean')),
        ]), numeric_columns),
        
        # Для категориальных - сначала импутация, затем one-hot кодирование
        ('cat', Pipeline([
            ('imputer', SimpleImputer(strategy='most_frequent')),  # 'constant': заполняет константой, которую можно указать через параметр fill_value
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ]), non_numeric_columns)
    ], 
    sparse_threshold=0,  # Это заставит возвращать dense матрицу вместо sparse
    remainder='drop'  # Все остальные столбцы не будут включены в результат; passthrough - оставить нетронутыми
)

# %% [markdown]
# ### 2.3. Разбиение данных на обучающую и тестовую выборки

# %%
RANDOM_STATE = 42

# %%
# Катбуст сам выбирает даныне для валидации, поэтому отсекаем данные только для теста
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=RANDOM_STATE)

# Проверка размера полученных наборов
print(f'Train size: {len(X_train)}')
print(f'Test size: {len(X_test)}')
# Out:
# Train size: 1022
# Test size: 438

# %% [markdown]
# ### 2.4. Подбираем гиперпараметры с помощью optuna
# Ниже схема "идеального" мира. как надо делать. но могут быть нюансы, например, если изначально данных и так мало...

# %%
# ┌─────────────────────────────────────────┐
# │       Исходный набор данных (100%)      │
# └─────────────────────────────────────────┘
#                      │
#                      │ разделяем
#                      ▼
# ┌─────────────────────────┐    ┌──────────────────┐
# │ Обучающий набор (80-90%)│    │ Тестовый (10-20%)│
# └─────────────────────────┘    └──────────────────┘
#            │                             │
#            ▼                             │
# ┌───────────────────────────────┐        │
# │   Подбор гиперпараметров      │        │
# │   (кросс-валидация внутри     │        │
# │          Optuna)              │        │
# └───────────────────────────────┘        │
#            │                             │
#            ▼                             │
# ┌───────────────────────────────┐        │
# │ Финальная модель с лучшими    │        │
# │ параметрами (обучение на      │        │
# │     полном обучающем наборе)  │        │
# └───────────────────────────────┘        │
#            │                             ▼
#            └────────────────────────► Оценка качества
#                                       (только 1 раз!)

# %%
def objective(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 800, 2000),
        'depth': trial.suggest_int('depth', 4, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.03, 0.2),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1.0, 10.0),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
        'silent': True,
        'random_seed': RANDOM_STATE,
    }
    
    pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('model', CatBoostRegressor(**params))
    ])

    # При подборе параметров через Optuna используй кросс-валидацию внутри самой Optuna, чтобы модель не переобучилась под одно разбиение, если делать просто оценку через RMSE без cross_val_score, то результаты будут завышены
    
    # Передаем только X_train часть, потом протестируем на X_test
    # score = cross_val_score(pipeline, X_train, y_train, scoring='neg_root_mean_squared_error', cv=5, n_jobs=-1)
    # Передав выше лишь часть данных, получил сильную просадку в качестве, поэтому передаем все данные, возможно, если бы данных было много изначально, то можно было бы передавать часть данных
    score = cross_val_score(pipeline, X, y, scoring='neg_root_mean_squared_error', cv=5, n_jobs=-1)
    return -score.mean()

# %%
# direction='minimize' - потому что мы хотим минимизировать RMSE. Т.е. в direction задается, что мы хотим сделать с целевой метрикой в процессе экспериментов - максимизировать ее или минимизировать. Минимизируем, например, ошибки. Максимизируем, например, точность.
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=200)  # n_trials - количество итераций (изменений гиперпараметров)
# Out:
# [I 2025-03-26 16:00:32,099] A new study created in memory with name: no-name-1c8240af-1a94-4739-9d2f-4d4b17bffae4
# [I 2025-03-26 16:01:15,013] Trial 0 finished with value: 28060.503398641846 and parameters: {'iterations': 1862, 'depth': 10, 'learning_rate': 0.15164284826591956, 'l2_leaf_reg': 9.573472207895584, 'bagging_temperature': 0.9908393796255972}. Best is trial 0 with value: 28060.503398641846.
# [I 2025-03-26 16:01:18,145] Trial 1 finished with value: 25848.48366528706 and parameters: {'iterations': 1191, 'depth': 5, 'learning_rate': 0.08974271467117986, 'l2_leaf_reg': 3.7715730984143856, 'bagging_temperature': 0.10658165626346527}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:01:26,367] Trial 2 finished with value: 27794.816516079787 and parameters: {'iterations': 1785, 'depth': 7, 'learning_rate': 0.19428149209524823, 'l2_leaf_reg': 1.4590191674350446, 'bagging_temperature': 0.02404819293092131}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:01:29,805] Trial 3 finished with value: 26403.934566346747 and parameters: {'iterations': 1228, 'depth': 6, 'learning_rate': 0.05819523192072532, 'l2_leaf_reg': 9.236074299676414, 'bagging_temperature': 0.8396537727902271}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:01:32,248] Trial 4 finished with value: 26138.317715563193 and parameters: {'iterations': 1804, 'depth': 4, 'learning_rate': 0.047340849824388076, 'l2_leaf_reg': 4.736501652432581, 'bagging_temperature': 0.5368248864738122}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:01:44,510] Trial 5 finished with value: 26579.3068835055 and parameters: {'iterations': 1618, 'depth': 8, 'learning_rate': 0.06262735800631108, 'l2_leaf_reg': 8.828886689546525, 'bagging_temperature': 0.27715670257572544}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:01:45,922] Trial 6 finished with value: 26931.066512032186 and parameters: {'iterations': 962, 'depth': 4, 'learning_rate': 0.09504786751104921, 'l2_leaf_reg': 6.169382672262727, 'bagging_temperature': 0.8296088020740077}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:02:11,339] Trial 7 finished with value: 27669.287507299297 and parameters: {'iterations': 1470, 'depth': 9, 'learning_rate': 0.12703045686393605, 'l2_leaf_reg': 6.010965777840056, 'bagging_temperature': 0.7363158218902498}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:02:25,283] Trial 8 finished with value: 27542.816808487034 and parameters: {'iterations': 1879, 'depth': 8, 'learning_rate': 0.1886287821201313, 'l2_leaf_reg': 9.789846005169196, 'bagging_temperature': 0.8497906434335181}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:02:36,795] Trial 9 finished with value: 27912.98983137359 and parameters: {'iterations': 1544, 'depth': 8, 'learning_rate': 0.15074090125698636, 'l2_leaf_reg': 6.540807928929983, 'bagging_temperature': 0.12717524684239834}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:02:39,262] Trial 10 finished with value: 26550.526683448676 and parameters: {'iterations': 1180, 'depth': 5, 'learning_rate': 0.09219226062813986, 'l2_leaf_reg': 2.38157269341967, 'bagging_temperature': 0.370251184789055}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:02:40,552] Trial 11 finished with value: 26537.778567234916 and parameters: {'iterations': 817, 'depth': 4, 'learning_rate': 0.035006478892688805, 'l2_leaf_reg': 3.6377538880540383, 'bagging_temperature': 0.5642444624726}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:02:43,171] Trial 12 finished with value: 26196.122489014728 and parameters: {'iterations': 1317, 'depth': 5, 'learning_rate': 0.030491058453475973, 'l2_leaf_reg': 4.078863551180213, 'bagging_temperature': 0.5653936488392668}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:02:45,300] Trial 13 finished with value: 26360.17453035457 and parameters: {'iterations': 1062, 'depth': 5, 'learning_rate': 0.07363384926351524, 'l2_leaf_reg': 4.41396212602489, 'bagging_temperature': 0.3722246389849579}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:02:50,181] Trial 14 finished with value: 26649.14802599257 and parameters: {'iterations': 1666, 'depth': 6, 'learning_rate': 0.11160310462604826, 'l2_leaf_reg': 3.140056175753515, 'bagging_temperature': 0.17845624931149884}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:02:53,039] Trial 15 finished with value: 26617.978835379792 and parameters: {'iterations': 1997, 'depth': 4, 'learning_rate': 0.051300659001994056, 'l2_leaf_reg': 7.693757043178824, 'bagging_temperature': 0.4572349007710842}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:02:57,200] Trial 16 finished with value: 26050.30545715869 and parameters: {'iterations': 1395, 'depth': 6, 'learning_rate': 0.0870734794080283, 'l2_leaf_reg': 4.556923069174323, 'bagging_temperature': 0.6743505286780103}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:03:01,123] Trial 17 finished with value: 25957.724100218908 and parameters: {'iterations': 1331, 'depth': 6, 'learning_rate': 0.0811300086918989, 'l2_leaf_reg': 5.187480579603545, 'bagging_temperature': 0.6675706336966681}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:03:05,910] Trial 18 finished with value: 26287.450121570524 and parameters: {'iterations': 1090, 'depth': 7, 'learning_rate': 0.11816893720097717, 'l2_leaf_reg': 2.5279186048538222, 'bagging_temperature': 0.0398710359436113}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:03:09,714] Trial 19 finished with value: 26248.055061382078 and parameters: {'iterations': 1330, 'depth': 6, 'learning_rate': 0.07771654060577314, 'l2_leaf_reg': 5.282931742582435, 'bagging_temperature': 0.6815790509926365}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:03:15,040] Trial 20 finished with value: 26921.356764008826 and parameters: {'iterations': 1204, 'depth': 7, 'learning_rate': 0.13856965291043982, 'l2_leaf_reg': 7.596019323224542, 'bagging_temperature': 0.2414072960396197}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:03:19,167] Trial 21 finished with value: 26296.48353257782 and parameters: {'iterations': 1446, 'depth': 6, 'learning_rate': 0.09039844739276977, 'l2_leaf_reg': 4.987909321896463, 'bagging_temperature': 0.6722672988534686}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:03:21,779] Trial 22 finished with value: 26853.284631346003 and parameters: {'iterations': 1307, 'depth': 5, 'learning_rate': 0.10402678237356305, 'l2_leaf_reg': 3.4596862286976493, 'bagging_temperature': 0.6631233309093278}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:03:25,976] Trial 23 finished with value: 26136.156353818038 and parameters: {'iterations': 1415, 'depth': 6, 'learning_rate': 0.08127529050216149, 'l2_leaf_reg': 5.662242895985987, 'bagging_temperature': 0.44564960659475816}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:03:28,098] Trial 24 finished with value: 26616.974947942035 and parameters: {'iterations': 1012, 'depth': 5, 'learning_rate': 0.06871866338525974, 'l2_leaf_reg': 7.280417804957535, 'bagging_temperature': 0.7686867052688391}. Best is trial 1 with value: 25848.48366528706.
# [I 2025-03-26 16:03:32,036] Trial 25 finished with value: 25754.640803367096 and parameters: {'iterations': 889, 'depth': 7, 'learning_rate': 0.10645703623851707, 'l2_leaf_reg': 2.636897319560501, 'bagging_temperature': 0.9288247388274165}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:03:35,595] Trial 26 finished with value: 26259.341928523405 and parameters: {'iterations': 806, 'depth': 7, 'learning_rate': 0.10151891414466874, 'l2_leaf_reg': 1.1924774222680588, 'bagging_temperature': 0.9556050918155529}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:03:39,619] Trial 27 finished with value: 27245.761922546848 and parameters: {'iterations': 910, 'depth': 7, 'learning_rate': 0.1321822497591701, 'l2_leaf_reg': 2.4682758059027554, 'bagging_temperature': 0.9177243646870776}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:03:58,902] Trial 28 finished with value: 28464.475388359548 and parameters: {'iterations': 1122, 'depth': 9, 'learning_rate': 0.11490636328497114, 'l2_leaf_reg': 1.7115840572828853, 'bagging_temperature': 0.8931921011536541}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:04:14,623] Trial 29 finished with value: 28507.633411613904 and parameters: {'iterations': 918, 'depth': 9, 'learning_rate': 0.17962769993820776, 'l2_leaf_reg': 3.0823443721324493, 'bagging_temperature': 0.9808017196081765}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:04:43,065] Trial 30 finished with value: 28594.72133345909 and parameters: {'iterations': 1276, 'depth': 10, 'learning_rate': 0.15992334780080833, 'l2_leaf_reg': 3.932824538816905, 'bagging_temperature': 0.5965844394517639}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:04:47,608] Trial 31 finished with value: 26391.46499040063 and parameters: {'iterations': 1532, 'depth': 6, 'learning_rate': 0.08208142855872635, 'l2_leaf_reg': 4.5852777731047345, 'bagging_temperature': 0.7329418960407834}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:04:52,607] Trial 32 finished with value: 26683.86788048544 and parameters: {'iterations': 1139, 'depth': 7, 'learning_rate': 0.10535833038757449, 'l2_leaf_reg': 1.8507729480789408, 'bagging_temperature': 0.4905820235153063}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:04:56,542] Trial 33 finished with value: 26406.308154857532 and parameters: {'iterations': 1380, 'depth': 6, 'learning_rate': 0.08524611321479762, 'l2_leaf_reg': 3.0437159631268242, 'bagging_temperature': 0.806011275218216}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:04:59,547] Trial 34 finished with value: 26458.14309926335 and parameters: {'iterations': 1521, 'depth': 5, 'learning_rate': 0.06785230841909712, 'l2_leaf_reg': 4.212627957864836, 'bagging_temperature': 0.640248457810974}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:03,235] Trial 35 finished with value: 26349.855353461004 and parameters: {'iterations': 1231, 'depth': 6, 'learning_rate': 0.05253664834223637, 'l2_leaf_reg': 5.160625249080658, 'bagging_temperature': 0.35314580792377914}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:10,093] Trial 36 finished with value: 27148.592412525857 and parameters: {'iterations': 1605, 'depth': 7, 'learning_rate': 0.12226482557048318, 'l2_leaf_reg': 3.6918079333369205, 'bagging_temperature': 0.6186406841295005}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:12,798] Trial 37 finished with value: 26461.159455665642 and parameters: {'iterations': 1368, 'depth': 5, 'learning_rate': 0.09898546188938703, 'l2_leaf_reg': 6.737599231215612, 'bagging_temperature': 0.7343698850401016}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:20,370] Trial 38 finished with value: 26289.57338782494 and parameters: {'iterations': 1023, 'depth': 8, 'learning_rate': 0.04223893784829192, 'l2_leaf_reg': 5.7284095528599845, 'bagging_temperature': 0.8866056877734225}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:25,093] Trial 39 finished with value: 26463.118735570355 and parameters: {'iterations': 1694, 'depth': 6, 'learning_rate': 0.06396891902283244, 'l2_leaf_reg': 2.1358942986511824, 'bagging_temperature': 0.06186521026531522}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:34,340] Trial 40 finished with value: 26918.674292660202 and parameters: {'iterations': 1255, 'depth': 8, 'learning_rate': 0.08957655815130007, 'l2_leaf_reg': 4.906387329976193, 'bagging_temperature': 0.5197767126720351}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:38,338] Trial 41 finished with value: 26163.98034333401 and parameters: {'iterations': 1406, 'depth': 6, 'learning_rate': 0.07823645008419432, 'l2_leaf_reg': 5.563497097834341, 'bagging_temperature': 0.4197111538575442}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:42,557] Trial 42 finished with value: 26032.670166523785 and parameters: {'iterations': 1458, 'depth': 6, 'learning_rate': 0.057943071672424004, 'l2_leaf_reg': 6.146592846531403, 'bagging_temperature': 0.1253530528716697}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:48,936] Trial 43 finished with value: 26054.006575860752 and parameters: {'iterations': 1465, 'depth': 7, 'learning_rate': 0.06162157065380595, 'l2_leaf_reg': 6.247071928272796, 'bagging_temperature': 0.11615617941839171}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:51,301] Trial 44 finished with value: 26274.397806010686 and parameters: {'iterations': 1175, 'depth': 5, 'learning_rate': 0.058086364008554006, 'l2_leaf_reg': 6.802190246111968, 'bagging_temperature': 0.2791711202928311}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:53,617] Trial 45 finished with value: 26691.654144723747 and parameters: {'iterations': 1588, 'depth': 4, 'learning_rate': 0.09471724962343256, 'l2_leaf_reg': 4.471154151141297, 'bagging_temperature': 0.14033593558590537}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:05:57,367] Trial 46 finished with value: 26750.37570881369 and parameters: {'iterations': 1350, 'depth': 6, 'learning_rate': 0.07370644269549308, 'l2_leaf_reg': 8.59328864848592, 'bagging_temperature': 0.19447472491437845}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:00,387] Trial 47 finished with value: 26980.171032980877 and parameters: {'iterations': 1504, 'depth': 5, 'learning_rate': 0.10795398156317353, 'l2_leaf_reg': 6.112763173060955, 'bagging_temperature': 0.0806450702131617}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:05,020] Trial 48 finished with value: 26359.253354085784 and parameters: {'iterations': 1683, 'depth': 6, 'learning_rate': 0.045081132163666396, 'l2_leaf_reg': 2.8166323182445154, 'bagging_temperature': 0.008774222327865483}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:10,791] Trial 49 finished with value: 26166.13193228833 and parameters: {'iterations': 1300, 'depth': 7, 'learning_rate': 0.054856610144507115, 'l2_leaf_reg': 3.6714754459099064, 'bagging_temperature': 0.2931318252599009}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:12,248] Trial 50 finished with value: 26215.059361707245 and parameters: {'iterations': 888, 'depth': 4, 'learning_rate': 0.09662078469899367, 'l2_leaf_reg': 4.771435252333934, 'bagging_temperature': 0.8101535054251163}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:18,658] Trial 51 finished with value: 26533.666168471285 and parameters: {'iterations': 1465, 'depth': 7, 'learning_rate': 0.06245284153758254, 'l2_leaf_reg': 6.226847974250424, 'bagging_temperature': 0.09884713286655142}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:29,349] Trial 52 finished with value: 26327.00486309865 and parameters: {'iterations': 1458, 'depth': 8, 'learning_rate': 0.03967582599734612, 'l2_leaf_reg': 7.275810940921406, 'bagging_temperature': 0.17749167355369042}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:36,267] Trial 53 finished with value: 26512.678927772406 and parameters: {'iterations': 1576, 'depth': 7, 'learning_rate': 0.08632569568676815, 'l2_leaf_reg': 5.334802509458873, 'bagging_temperature': 0.23865558549360252}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:42,871] Trial 54 finished with value: 26169.636263401968 and parameters: {'iterations': 1395, 'depth': 7, 'learning_rate': 0.07333122839790822, 'l2_leaf_reg': 4.057866280599502, 'bagging_temperature': 0.12873299132311244}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:46,960] Trial 55 finished with value: 25898.648317179315 and parameters: {'iterations': 1431, 'depth': 6, 'learning_rate': 0.06858812460594058, 'l2_leaf_reg': 5.890137828197832, 'bagging_temperature': 0.0016451949719989978}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:50,531] Trial 56 finished with value: 26612.447644623473 and parameters: {'iterations': 1812, 'depth': 5, 'learning_rate': 0.07123843711737966, 'l2_leaf_reg': 5.792127301679505, 'bagging_temperature': 0.0054148419468411785}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:54,458] Trial 57 finished with value: 26598.005445455132 and parameters: {'iterations': 1338, 'depth': 6, 'learning_rate': 0.09103606787672969, 'l2_leaf_reg': 6.60563488978131, 'bagging_temperature': 0.046935711937481625}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:06:58,607] Trial 58 finished with value: 26906.1991316954 and parameters: {'iterations': 1425, 'depth': 6, 'learning_rate': 0.11105051003761182, 'l2_leaf_reg': 3.2902806807799734, 'bagging_temperature': 0.7669853472967502}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:07:01,315] Trial 59 finished with value: 26284.821794538882 and parameters: {'iterations': 1257, 'depth': 5, 'learning_rate': 0.07881414521935907, 'l2_leaf_reg': 5.177308066627199, 'bagging_temperature': 0.5755801664495115}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:07:04,136] Trial 60 finished with value: 25997.997207375305 and parameters: {'iterations': 962, 'depth': 6, 'learning_rate': 0.05014336444219123, 'l2_leaf_reg': 4.363280690703052, 'bagging_temperature': 0.31352714942447707}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:07:06,990] Trial 61 finished with value: 25976.75890568344 and parameters: {'iterations': 956, 'depth': 6, 'learning_rate': 0.03565863518727247, 'l2_leaf_reg': 4.270913694788963, 'bagging_temperature': 0.3220767841588929}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:07:09,461] Trial 62 finished with value: 26016.856553169615 and parameters: {'iterations': 858, 'depth': 6, 'learning_rate': 0.037264495502553806, 'l2_leaf_reg': 4.290132809792102, 'bagging_temperature': 0.32786534846850746}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:07:12,038] Trial 63 finished with value: 26064.73153331041 and parameters: {'iterations': 853, 'depth': 6, 'learning_rate': 0.047627029342042534, 'l2_leaf_reg': 4.228662352608872, 'bagging_temperature': 0.3453644504620157}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:07:14,499] Trial 64 finished with value: 26086.21771822436 and parameters: {'iterations': 853, 'depth': 6, 'learning_rate': 0.03165041987940012, 'l2_leaf_reg': 3.8662922391393937, 'bagging_temperature': 0.4015921940174205}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:07:16,484] Trial 65 finished with value: 25996.169816558544 and parameters: {'iterations': 987, 'depth': 5, 'learning_rate': 0.035775689709955684, 'l2_leaf_reg': 2.798543991853488, 'bagging_temperature': 0.31963793050460254}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:07:17,958] Trial 66 finished with value: 26077.528114451547 and parameters: {'iterations': 960, 'depth': 4, 'learning_rate': 0.048417201079754266, 'l2_leaf_reg': 2.772585241832676, 'bagging_temperature': 0.2120227415199703}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:07:19,965] Trial 67 finished with value: 25959.744714409047 and parameters: {'iterations': 964, 'depth': 5, 'learning_rate': 0.03285637398124325, 'l2_leaf_reg': 2.244504484410246, 'bagging_temperature': 0.3107823630044478}. Best is trial 25 with value: 25754.640803367096.
# [I 2025-03-26 16:07:22,126] Trial 68 finished with value: 25624.240048443782 and parameters: {'iterations': 1046, 'depth': 5, 'learning_rate': 0.031958267828942524, 'l2_leaf_reg': 1.5106888151125992, 'bagging_temperature': 0.4059608316000414}. Best is trial 68 with value: 25624.240048443782.
# [I 2025-03-26 16:07:24,337] Trial 69 finished with value: 25380.073387703964 and parameters: {'iterations': 1088, 'depth': 5, 'learning_rate': 0.0332300336286512, 'l2_leaf_reg': 1.2446634848732656, 'bagging_temperature': 0.39453417756370984}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:26,495] Trial 70 finished with value: 25795.81225153987 and parameters: {'iterations': 1073, 'depth': 5, 'learning_rate': 0.04247977924017453, 'l2_leaf_reg': 1.6139467567881614, 'bagging_temperature': 0.47816389000804654}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:28,756] Trial 71 finished with value: 25570.425361510926 and parameters: {'iterations': 1059, 'depth': 5, 'learning_rate': 0.04307735531238843, 'l2_leaf_reg': 1.3312154404252687, 'bagging_temperature': 0.4867406336543367}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:30,399] Trial 72 finished with value: 25535.482394087558 and parameters: {'iterations': 1036, 'depth': 4, 'learning_rate': 0.04168112720935966, 'l2_leaf_reg': 1.1959949091368371, 'bagging_temperature': 0.4700951006356672}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:31,971] Trial 73 finished with value: 25457.93694906082 and parameters: {'iterations': 1065, 'depth': 4, 'learning_rate': 0.04533934989812742, 'l2_leaf_reg': 1.0021147148686311, 'bagging_temperature': 0.4817292397287581}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:33,675] Trial 74 finished with value: 25550.7903941125 and parameters: {'iterations': 1052, 'depth': 4, 'learning_rate': 0.042416263990844416, 'l2_leaf_reg': 1.2261026579074377, 'bagging_temperature': 0.47470661584536356}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:35,306] Trial 75 finished with value: 25415.414893075886 and parameters: {'iterations': 1080, 'depth': 4, 'learning_rate': 0.042269232963830616, 'l2_leaf_reg': 1.0946947748843474, 'bagging_temperature': 0.48811824559454753}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:36,822] Trial 76 finished with value: 25493.585115708134 and parameters: {'iterations': 1029, 'depth': 4, 'learning_rate': 0.04258956990014642, 'l2_leaf_reg': 1.0187439380851502, 'bagging_temperature': 0.5203707847869844}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:38,341] Trial 77 finished with value: 25567.929876772665 and parameters: {'iterations': 1030, 'depth': 4, 'learning_rate': 0.04083566608165575, 'l2_leaf_reg': 1.0094263449297072, 'bagging_temperature': 0.5285666551571627}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:40,016] Trial 78 finished with value: 25709.260585114975 and parameters: {'iterations': 1113, 'depth': 4, 'learning_rate': 0.04195328580439495, 'l2_leaf_reg': 1.0566592944297222, 'bagging_temperature': 0.525474565599766}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:41,734] Trial 79 finished with value: 25774.97845446554 and parameters: {'iterations': 1158, 'depth': 4, 'learning_rate': 0.054400676561795445, 'l2_leaf_reg': 1.3201645976249934, 'bagging_temperature': 0.4445914384091651}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:43,297] Trial 80 finished with value: 25828.418366632704 and parameters: {'iterations': 1020, 'depth': 4, 'learning_rate': 0.04500557286230121, 'l2_leaf_reg': 2.026064467822605, 'bagging_temperature': 0.5454442217406398}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:44,895] Trial 81 finished with value: 25986.38998409636 and parameters: {'iterations': 1064, 'depth': 4, 'learning_rate': 0.03031609765971849, 'l2_leaf_reg': 1.4097400808845473, 'bagging_temperature': 0.39225493283770974}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:46,457] Trial 82 finished with value: 25434.5061689064 and parameters: {'iterations': 1041, 'depth': 4, 'learning_rate': 0.03906231016044483, 'l2_leaf_reg': 1.0025113104837884, 'bagging_temperature': 0.46925104907622056}. Best is trial 69 with value: 25380.073387703964.
# [I 2025-03-26 16:07:48,084] Trial 83 finished with value: 24922.21406237376 and parameters: {'iterations': 1098, 'depth': 4, 'learning_rate': 0.04000102325817965, 'l2_leaf_reg': 1.0885027090339108, 'bagging_temperature': 0.4668814661901983}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:07:49,745] Trial 84 finished with value: 25223.541183603134 and parameters: {'iterations': 1094, 'depth': 4, 'learning_rate': 0.03869860328570773, 'l2_leaf_reg': 1.0119064116453418, 'bagging_temperature': 0.44021253506618596}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:07:51,412] Trial 85 finished with value: 25900.668976042878 and parameters: {'iterations': 1123, 'depth': 4, 'learning_rate': 0.03746767084073972, 'l2_leaf_reg': 1.8073777559115838, 'bagging_temperature': 0.44851213843634274}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:07:53,311] Trial 86 finished with value: 25851.140191044127 and parameters: {'iterations': 1213, 'depth': 4, 'learning_rate': 0.0494273018493709, 'l2_leaf_reg': 1.1885248868981215, 'bagging_temperature': 0.46668261549150375}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:07:54,982] Trial 87 finished with value: 25956.971963085445 and parameters: {'iterations': 1096, 'depth': 4, 'learning_rate': 0.053448888976789954, 'l2_leaf_reg': 1.9077464241956936, 'bagging_temperature': 0.506750278941498}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:07:56,733] Trial 88 finished with value: 25930.248515951673 and parameters: {'iterations': 1156, 'depth': 4, 'learning_rate': 0.038652922788862926, 'l2_leaf_reg': 1.5936060977615547, 'bagging_temperature': 0.4247617162203673}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:07:58,459] Trial 89 finished with value: 25620.529783477148 and parameters: {'iterations': 1092, 'depth': 4, 'learning_rate': 0.04612064282853824, 'l2_leaf_reg': 1.055804264444588, 'bagging_temperature': 0.5527982609581733}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:00,107] Trial 90 finished with value: 25829.91465267889 and parameters: {'iterations': 989, 'depth': 4, 'learning_rate': 0.05859138365331497, 'l2_leaf_reg': 1.7006942797171316, 'bagging_temperature': 0.3715028271458801}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:01,683] Trial 91 finished with value: 25321.477278187547 and parameters: {'iterations': 1035, 'depth': 4, 'learning_rate': 0.03888362611957444, 'l2_leaf_reg': 1.2257059993060706, 'bagging_temperature': 0.5935685286715384}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:03,199] Trial 92 finished with value: 25563.06851998713 and parameters: {'iterations': 991, 'depth': 4, 'learning_rate': 0.034504142144491434, 'l2_leaf_reg': 1.266553874611846, 'bagging_temperature': 0.5974740035680107}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:04,639] Trial 93 finished with value: 25926.474782112535 and parameters: {'iterations': 936, 'depth': 4, 'learning_rate': 0.03906173880110837, 'l2_leaf_reg': 1.4771253226871508, 'bagging_temperature': 0.5814934207539678}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:06,320] Trial 94 finished with value: 26237.018092018407 and parameters: {'iterations': 1083, 'depth': 4, 'learning_rate': 0.03017624809478285, 'l2_leaf_reg': 2.3104216495915852, 'bagging_temperature': 0.42318754144491416}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:08,095] Trial 95 finished with value: 25302.155760480335 and parameters: {'iterations': 1135, 'depth': 4, 'learning_rate': 0.0458087095059902, 'l2_leaf_reg': 1.9938619771242219, 'bagging_temperature': 0.5018743752519872}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:09,920] Trial 96 finished with value: 25812.961226386346 and parameters: {'iterations': 1139, 'depth': 4, 'learning_rate': 0.05172223821212407, 'l2_leaf_reg': 2.0154726023072413, 'bagging_temperature': 0.5040807866116355}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:11,556] Trial 97 finished with value: 25593.43948792626 and parameters: {'iterations': 1000, 'depth': 4, 'learning_rate': 0.05796551261954785, 'l2_leaf_reg': 1.0135073944603923, 'bagging_temperature': 0.4430369951806112}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:13,379] Trial 98 finished with value: 25263.194131499455 and parameters: {'iterations': 1176, 'depth': 4, 'learning_rate': 0.04619099448041312, 'l2_leaf_reg': 1.6829728015755627, 'bagging_temperature': 0.6343318522768961}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:15,273] Trial 99 finished with value: 26144.498325101413 and parameters: {'iterations': 1179, 'depth': 4, 'learning_rate': 0.04762089580440043, 'l2_leaf_reg': 1.7563228467338148, 'bagging_temperature': 0.61792661981442}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:17,069] Trial 100 finished with value: 25690.305835897827 and parameters: {'iterations': 1202, 'depth': 4, 'learning_rate': 0.06584935706159159, 'l2_leaf_reg': 1.4824747280016901, 'bagging_temperature': 0.5563799759604416}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:18,675] Trial 101 finished with value: 25441.754291846813 and parameters: {'iterations': 1036, 'depth': 4, 'learning_rate': 0.03500623790694831, 'l2_leaf_reg': 1.2507810790283618, 'bagging_temperature': 0.6447107846752685}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:20,434] Trial 102 finished with value: 25834.108627787726 and parameters: {'iterations': 1114, 'depth': 4, 'learning_rate': 0.034624457372162076, 'l2_leaf_reg': 1.3997024827497357, 'bagging_temperature': 0.6340532175308309}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:22,233] Trial 103 finished with value: 26788.997589835104 and parameters: {'iterations': 1151, 'depth': 4, 'learning_rate': 0.15634294263562584, 'l2_leaf_reg': 2.128163631941424, 'bagging_temperature': 0.6614438980798376}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:23,939] Trial 104 finished with value: 25517.717750148124 and parameters: {'iterations': 1109, 'depth': 4, 'learning_rate': 0.03599846175014676, 'l2_leaf_reg': 1.645340037269305, 'bagging_temperature': 0.6961934823030943}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:25,662] Trial 105 finished with value: 25511.622212596518 and parameters: {'iterations': 1082, 'depth': 4, 'learning_rate': 0.04514816312267583, 'l2_leaf_reg': 1.9115916116962879, 'bagging_temperature': 0.7065290762471043}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:27,200] Trial 106 finished with value: 25784.63716313783 and parameters: {'iterations': 1017, 'depth': 4, 'learning_rate': 0.05109202710595045, 'l2_leaf_reg': 1.2444799027315714, 'bagging_temperature': 0.5970540124228253}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:29,106] Trial 107 finished with value: 25853.811288523408 and parameters: {'iterations': 933, 'depth': 5, 'learning_rate': 0.038455095266896756, 'l2_leaf_reg': 2.494062890471783, 'bagging_temperature': 0.5027213209154611}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:30,923] Trial 108 finished with value: 25821.510548554164 and parameters: {'iterations': 1181, 'depth': 4, 'learning_rate': 0.055342037860041375, 'l2_leaf_reg': 1.135840957864827, 'bagging_temperature': 0.5345880086065443}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:32,647] Trial 109 finished with value: 25652.70052336232 and parameters: {'iterations': 1137, 'depth': 4, 'learning_rate': 0.045918670358162175, 'l2_leaf_reg': 1.5024319325538704, 'bagging_temperature': 0.3890609679609398}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:34,556] Trial 110 finished with value: 25535.261730653445 and parameters: {'iterations': 1222, 'depth': 4, 'learning_rate': 0.033476012639510645, 'l2_leaf_reg': 1.0112647975379128, 'bagging_temperature': 0.5725284966334175}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:36,188] Trial 111 finished with value: 25868.211621420425 and parameters: {'iterations': 1071, 'depth': 4, 'learning_rate': 0.045315391698935295, 'l2_leaf_reg': 1.9386703145415907, 'bagging_temperature': 0.6837699063165985}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:37,855] Trial 112 finished with value: 27220.406606416458 and parameters: {'iterations': 1044, 'depth': 4, 'learning_rate': 0.14229337260755776, 'l2_leaf_reg': 1.7370338264161873, 'bagging_temperature': 0.6528188256952225}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:39,573] Trial 113 finished with value: 25701.518856776245 and parameters: {'iterations': 1090, 'depth': 4, 'learning_rate': 0.03914030520909481, 'l2_leaf_reg': 1.3477538256710504, 'bagging_temperature': 0.7222529548649501}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:41,099] Trial 114 finished with value: 25598.709662749938 and parameters: {'iterations': 1006, 'depth': 4, 'learning_rate': 0.048592110780729045, 'l2_leaf_reg': 2.2045333127483384, 'bagging_temperature': 0.5135605089614307}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:42,818] Trial 115 finished with value: 27272.672454800253 and parameters: {'iterations': 1076, 'depth': 4, 'learning_rate': 0.19824214926377523, 'l2_leaf_reg': 1.8710952288623972, 'bagging_temperature': 0.7666627817286584}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:45,757] Trial 116 finished with value: 25888.15132118172 and parameters: {'iterations': 1955, 'depth': 4, 'learning_rate': 0.04437878742592541, 'l2_leaf_reg': 1.51606314723278, 'bagging_temperature': 0.6188217238424695}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:48,023] Trial 117 finished with value: 25319.282983400364 and parameters: {'iterations': 1039, 'depth': 5, 'learning_rate': 0.03022507289992751, 'l2_leaf_reg': 1.1999753525029921, 'bagging_temperature': 0.43069671609033716}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:50,090] Trial 118 finished with value: 25612.888264641708 and parameters: {'iterations': 979, 'depth': 5, 'learning_rate': 0.030004287447447608, 'l2_leaf_reg': 1.2199364553020289, 'bagging_temperature': 0.46000843617073306}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:52,223] Trial 119 finished with value: 25625.49415374129 and parameters: {'iterations': 1030, 'depth': 5, 'learning_rate': 0.034279799010846976, 'l2_leaf_reg': 1.3949795215201442, 'bagging_temperature': 0.42846427663150594}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:54,528] Trial 120 finished with value: 25280.75848686825 and parameters: {'iterations': 1128, 'depth': 5, 'learning_rate': 0.04042763961230406, 'l2_leaf_reg': 1.648899708722348, 'bagging_temperature': 0.49595427099897565}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:56,846] Trial 121 finished with value: 25887.328028848984 and parameters: {'iterations': 1131, 'depth': 5, 'learning_rate': 0.040805726951344275, 'l2_leaf_reg': 1.6058338072110039, 'bagging_temperature': 0.4875626044836559}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:08:59,084] Trial 122 finished with value: 25508.876386514417 and parameters: {'iterations': 1045, 'depth': 5, 'learning_rate': 0.037111504648745186, 'l2_leaf_reg': 1.0105704103184023, 'bagging_temperature': 0.3575189911014686}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:01,497] Trial 123 finished with value: 27595.642497894813 and parameters: {'iterations': 1172, 'depth': 5, 'learning_rate': 0.17709128941306096, 'l2_leaf_reg': 1.2930670882636883, 'bagging_temperature': 0.4926500109902809}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:03,549] Trial 124 finished with value: 25113.026705205186 and parameters: {'iterations': 1241, 'depth': 4, 'learning_rate': 0.04004482965318904, 'l2_leaf_reg': 1.1742617552764971, 'bagging_temperature': 0.4079852791366401}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:30,166] Trial 125 finished with value: 28923.902412556792 and parameters: {'iterations': 1195, 'depth': 10, 'learning_rate': 0.0327266931010467, 'l2_leaf_reg': 1.6294958852311323, 'bagging_temperature': 0.38323549162940257}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:32,561] Trial 126 finished with value: 25645.643231544505 and parameters: {'iterations': 1110, 'depth': 5, 'learning_rate': 0.03854155025904598, 'l2_leaf_reg': 1.1865498520812274, 'bagging_temperature': 0.4085388881389225}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:34,565] Trial 127 finished with value: 25697.17741734127 and parameters: {'iterations': 1268, 'depth': 4, 'learning_rate': 0.05060781434074439, 'l2_leaf_reg': 1.3924309248522053, 'bagging_temperature': 0.43653805561104075}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:36,532] Trial 128 finished with value: 26027.22181710066 and parameters: {'iterations': 1228, 'depth': 4, 'learning_rate': 0.03566051060143571, 'l2_leaf_reg': 1.8128464459912583, 'bagging_temperature': 0.45781295898253915}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:38,452] Trial 129 finished with value: 26043.495092125395 and parameters: {'iterations': 1295, 'depth': 4, 'learning_rate': 0.04060031919506753, 'l2_leaf_reg': 2.119455432400255, 'bagging_temperature': 0.5413410347016799}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:40,224] Trial 130 finished with value: 25964.70196821431 and parameters: {'iterations': 1152, 'depth': 4, 'learning_rate': 0.0608363197477418, 'l2_leaf_reg': 1.2202924319843098, 'bagging_temperature': 0.40225037538145747}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:41,925] Trial 131 finished with value: 25451.735878166484 and parameters: {'iterations': 1060, 'depth': 4, 'learning_rate': 0.04281747169956385, 'l2_leaf_reg': 1.1082486708433885, 'bagging_temperature': 0.4690463126691382}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:43,535] Trial 132 finished with value: 25460.372987682604 and parameters: {'iterations': 1059, 'depth': 4, 'learning_rate': 0.043919051397386354, 'l2_leaf_reg': 1.52959355876969, 'bagging_temperature': 0.4676418977286634}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:45,225] Trial 133 finished with value: 25998.585282464242 and parameters: {'iterations': 1105, 'depth': 4, 'learning_rate': 0.04802022307748153, 'l2_leaf_reg': 1.1659851167721347, 'bagging_temperature': 0.4387345417144204}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:46,887] Trial 134 finished with value: 25656.541089517137 and parameters: {'iterations': 1126, 'depth': 4, 'learning_rate': 0.03342507017859106, 'l2_leaf_reg': 1.000561751357898, 'bagging_temperature': 0.4796210615976259}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:48,513] Trial 135 finished with value: 25863.13703142723 and parameters: {'iterations': 1054, 'depth': 4, 'learning_rate': 0.05383189351251709, 'l2_leaf_reg': 1.3934158262339387, 'bagging_temperature': 0.3388817534906041}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:50,052] Trial 136 finished with value: 25510.453945646732 and parameters: {'iterations': 1011, 'depth': 4, 'learning_rate': 0.040683821919339606, 'l2_leaf_reg': 1.665663221789341, 'bagging_temperature': 0.3609771504770564}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:52,306] Trial 137 finished with value: 27116.123731983167 and parameters: {'iterations': 1091, 'depth': 5, 'learning_rate': 0.037190224639943106, 'l2_leaf_reg': 9.329482152837759, 'bagging_temperature': 0.41147065775212155}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:54,192] Trial 138 finished with value: 25766.73628705214 and parameters: {'iterations': 1243, 'depth': 4, 'learning_rate': 0.031122645020747623, 'l2_leaf_reg': 1.319229453622029, 'bagging_temperature': 0.4540537928010514}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:56,590] Trial 139 finished with value: 26173.64128054675 and parameters: {'iterations': 1163, 'depth': 5, 'learning_rate': 0.04767644149787929, 'l2_leaf_reg': 1.7488120417982114, 'bagging_temperature': 0.49956272483780206}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:58,223] Trial 140 finished with value: 26899.57507252922 and parameters: {'iterations': 1063, 'depth': 4, 'learning_rate': 0.04273009126640975, 'l2_leaf_reg': 8.16776120021986, 'bagging_temperature': 0.42011583503554395}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:09:59,823] Trial 141 finished with value: 25633.301878543083 and parameters: {'iterations': 1056, 'depth': 4, 'learning_rate': 0.04355957661270577, 'l2_leaf_reg': 1.5448690981619562, 'bagging_temperature': 0.4606575915145999}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:01,549] Trial 142 finished with value: 25345.764143988898 and parameters: {'iterations': 1133, 'depth': 4, 'learning_rate': 0.03693263115124312, 'l2_leaf_reg': 1.199648688683244, 'bagging_temperature': 0.3754429318378638}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:03,296] Trial 143 finished with value: 25612.7156354826 and parameters: {'iterations': 1132, 'depth': 4, 'learning_rate': 0.036607421056561645, 'l2_leaf_reg': 1.1723685202112135, 'bagging_temperature': 0.3911457238795335}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:04,942] Trial 144 finished with value: 25226.586787478165 and parameters: {'iterations': 1101, 'depth': 4, 'learning_rate': 0.03970530100847836, 'l2_leaf_reg': 1.000494168495472, 'bagging_temperature': 0.37223652913984784}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:06,607] Trial 145 finished with value: 25600.464806161686 and parameters: {'iterations': 1102, 'depth': 4, 'learning_rate': 0.034021315614506574, 'l2_leaf_reg': 1.3575716509149582, 'bagging_temperature': 0.3737894813249847}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:27,050] Trial 146 finished with value: 27413.43877858844 and parameters: {'iterations': 1198, 'depth': 9, 'learning_rate': 0.030226567273444062, 'l2_leaf_reg': 9.87110956969046, 'bagging_temperature': 0.3776403280730441}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:28,817] Trial 147 finished with value: 25800.961883498956 and parameters: {'iterations': 1143, 'depth': 4, 'learning_rate': 0.037955809453072524, 'l2_leaf_reg': 1.4752796651836046, 'bagging_temperature': 0.34075341152448635}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:30,480] Trial 148 finished with value: 25563.877001973065 and parameters: {'iterations': 1091, 'depth': 4, 'learning_rate': 0.04069610841304059, 'l2_leaf_reg': 1.1553901993204279, 'bagging_temperature': 0.28965590839575306}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:32,048] Trial 149 finished with value: 25703.433691729726 and parameters: {'iterations': 1033, 'depth': 4, 'learning_rate': 0.034916734406805996, 'l2_leaf_reg': 2.0257772298767227, 'bagging_temperature': 0.4335233705547547}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:33,785] Trial 150 finished with value: 25911.68496487631 and parameters: {'iterations': 1178, 'depth': 4, 'learning_rate': 0.05056819148117696, 'l2_leaf_reg': 1.3091978271030347, 'bagging_temperature': 0.6251781459298914}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:35,463] Trial 151 finished with value: 25553.255808326543 and parameters: {'iterations': 1122, 'depth': 4, 'learning_rate': 0.045149209768211684, 'l2_leaf_reg': 1.017301819675124, 'bagging_temperature': 0.4832092890815144}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:37,047] Trial 152 finished with value: 24971.257671742285 and parameters: {'iterations': 977, 'depth': 4, 'learning_rate': 0.03995697423894969, 'l2_leaf_reg': 1.1531051757664361, 'bagging_temperature': 0.5146900605747141}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:38,626] Trial 153 finished with value: 25689.5245550766 and parameters: {'iterations': 979, 'depth': 4, 'learning_rate': 0.03889859503068565, 'l2_leaf_reg': 1.1767504436190417, 'bagging_temperature': 0.5200215983502249}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:40,199] Trial 154 finished with value: 25742.351309310394 and parameters: {'iterations': 936, 'depth': 4, 'learning_rate': 0.03419569515201359, 'l2_leaf_reg': 1.6535297226474985, 'bagging_temperature': 0.5588527300830027}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:41,743] Trial 155 finished with value: 25518.053699618 and parameters: {'iterations': 1007, 'depth': 4, 'learning_rate': 0.04053689636436282, 'l2_leaf_reg': 1.444952768870714, 'bagging_temperature': 0.5973325292495401}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:43,367] Trial 156 finished with value: 25646.40363216835 and parameters: {'iterations': 1082, 'depth': 4, 'learning_rate': 0.03711204507148013, 'l2_leaf_reg': 1.1976725667824661, 'bagging_temperature': 0.4224215316733475}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:44,812] Trial 157 finished with value: 25339.082754087736 and parameters: {'iterations': 893, 'depth': 4, 'learning_rate': 0.04720502264910711, 'l2_leaf_reg': 1.3664679753215354, 'bagging_temperature': 0.505961674720483}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:46,774] Trial 158 finished with value: 25719.53789334374 and parameters: {'iterations': 912, 'depth': 5, 'learning_rate': 0.05532211191335081, 'l2_leaf_reg': 1.804653161337364, 'bagging_temperature': 0.5104687157280726}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:48,099] Trial 159 finished with value: 25635.307922481352 and parameters: {'iterations': 827, 'depth': 4, 'learning_rate': 0.04727339991041508, 'l2_leaf_reg': 1.5801264749681951, 'bagging_temperature': 0.5859144518326916}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:49,680] Trial 160 finished with value: 25520.256270586462 and parameters: {'iterations': 971, 'depth': 4, 'learning_rate': 0.051683161327101254, 'l2_leaf_reg': 1.3595137150501166, 'bagging_temperature': 0.5364737865018594}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:51,070] Trial 161 finished with value: 25530.879327942363 and parameters: {'iterations': 870, 'depth': 4, 'learning_rate': 0.042753260862703854, 'l2_leaf_reg': 1.0225883230626513, 'bagging_temperature': 0.6510697830888618}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:52,719] Trial 162 finished with value: 25432.036138777872 and parameters: {'iterations': 1036, 'depth': 4, 'learning_rate': 0.04048227110645727, 'l2_leaf_reg': 1.2198491325627645, 'bagging_temperature': 0.46222035643746273}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:54,253] Trial 163 finished with value: 25780.273560370286 and parameters: {'iterations': 1026, 'depth': 4, 'learning_rate': 0.03293536684963835, 'l2_leaf_reg': 1.3541376029453525, 'bagging_temperature': 0.44874427929595545}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:55,717] Trial 164 finished with value: 25932.20197883527 and parameters: {'iterations': 895, 'depth': 4, 'learning_rate': 0.039407263698689216, 'l2_leaf_reg': 1.5316852785254174, 'bagging_temperature': 0.40443949087458997}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:57,423] Trial 165 finished with value: 25763.402973885568 and parameters: {'iterations': 1106, 'depth': 4, 'learning_rate': 0.04725327793230169, 'l2_leaf_reg': 1.2240758950741988, 'bagging_temperature': 0.4989368292293246}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:10:58,912] Trial 166 finished with value: 26133.210096601404 and parameters: {'iterations': 942, 'depth': 4, 'learning_rate': 0.030310804970589245, 'l2_leaf_reg': 1.7611688729616328, 'bagging_temperature': 0.43437528313499824}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:00,515] Trial 167 finished with value: 25847.74746910497 and parameters: {'iterations': 996, 'depth': 4, 'learning_rate': 0.03725859273503849, 'l2_leaf_reg': 1.448271838921435, 'bagging_temperature': 0.5312544487631685}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:02,246] Trial 168 finished with value: 25493.0956286472 and parameters: {'iterations': 1152, 'depth': 4, 'learning_rate': 0.03513031418971977, 'l2_leaf_reg': 1.0055544219710615, 'bagging_temperature': 0.4767643924216926}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:04,461] Trial 169 finished with value: 25843.04115711545 and parameters: {'iterations': 1077, 'depth': 5, 'learning_rate': 0.040807111746132024, 'l2_leaf_reg': 1.9055104308347228, 'bagging_temperature': 0.38902195749575613}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:06,196] Trial 170 finished with value: 25759.97690221452 and parameters: {'iterations': 1044, 'depth': 4, 'learning_rate': 0.044849279208767995, 'l2_leaf_reg': 1.2321133959333737, 'bagging_temperature': 0.3602815492467118}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:07,912] Trial 171 finished with value: 25252.02569223748 and parameters: {'iterations': 1119, 'depth': 4, 'learning_rate': 0.042209755988862833, 'l2_leaf_reg': 1.0005909873375096, 'bagging_temperature': 0.4549239219951885}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:09,990] Trial 172 finished with value: 25746.76818217531 and parameters: {'iterations': 1124, 'depth': 4, 'learning_rate': 0.03777523380522227, 'l2_leaf_reg': 1.302018930731201, 'bagging_temperature': 0.45181886814419664}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:11,953] Trial 173 finished with value: 25638.82830166609 and parameters: {'iterations': 1102, 'depth': 4, 'learning_rate': 0.0434040954676593, 'l2_leaf_reg': 1.0013489161379803, 'bagging_temperature': 0.4162894917326969}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:13,811] Trial 174 finished with value: 25157.490790019663 and parameters: {'iterations': 1155, 'depth': 4, 'learning_rate': 0.048886515820414, 'l2_leaf_reg': 1.605557928032165, 'bagging_temperature': 0.511324427797788}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:15,713] Trial 175 finished with value: 26032.474946412058 and parameters: {'iterations': 1167, 'depth': 4, 'learning_rate': 0.0492733927383877, 'l2_leaf_reg': 1.5905037641012922, 'bagging_temperature': 0.4956935487887494}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:17,601] Trial 176 finished with value: 26389.714178530452 and parameters: {'iterations': 1199, 'depth': 4, 'learning_rate': 0.046763267173176346, 'l2_leaf_reg': 1.4488694295389781, 'bagging_temperature': 0.5168118710290236}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:19,543] Trial 177 finished with value: 25229.438271944746 and parameters: {'iterations': 1132, 'depth': 4, 'learning_rate': 0.0521544046325, 'l2_leaf_reg': 1.1737726149441767, 'bagging_temperature': 0.46873599153661666}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:21,480] Trial 178 finished with value: 25591.985836308744 and parameters: {'iterations': 1157, 'depth': 4, 'learning_rate': 0.05312041794344409, 'l2_leaf_reg': 1.6989921103791126, 'bagging_temperature': 0.49044127835355045}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:23,329] Trial 179 finished with value: 25681.55396573761 and parameters: {'iterations': 1137, 'depth': 4, 'learning_rate': 0.0498093387343445, 'l2_leaf_reg': 1.1609570828778344, 'bagging_temperature': 0.5509642906098304}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:26,106] Trial 180 finished with value: 25882.05722442793 and parameters: {'iterations': 1184, 'depth': 4, 'learning_rate': 0.05705240507215837, 'l2_leaf_reg': 1.370736598637082, 'bagging_temperature': 0.4466511064045845}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:27,966] Trial 181 finished with value: 25200.379331863627 and parameters: {'iterations': 1107, 'depth': 4, 'learning_rate': 0.04213698967216461, 'l2_leaf_reg': 1.1579019229412502, 'bagging_temperature': 0.46442906614768914}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:29,724] Trial 182 finished with value: 25468.094771178232 and parameters: {'iterations': 1123, 'depth': 4, 'learning_rate': 0.04209591350698129, 'l2_leaf_reg': 1.1726628192308057, 'bagging_temperature': 0.4782210150780618}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:31,516] Trial 183 finished with value: 25578.957461584534 and parameters: {'iterations': 1115, 'depth': 4, 'learning_rate': 0.04561550270351301, 'l2_leaf_reg': 1.5327019611157124, 'bagging_temperature': 0.4582299917077448}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:33,217] Trial 184 finished with value: 25588.896889441985 and parameters: {'iterations': 1087, 'depth': 4, 'learning_rate': 0.04078067827721266, 'l2_leaf_reg': 1.3247429813203713, 'bagging_temperature': 0.4276523413772342}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:35,075] Trial 185 finished with value: 25838.92283683264 and parameters: {'iterations': 1145, 'depth': 4, 'learning_rate': 0.04809895852883109, 'l2_leaf_reg': 1.1594297524038315, 'bagging_temperature': 0.5060467298518261}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:37,101] Trial 186 finished with value: 25580.944046939563 and parameters: {'iterations': 1075, 'depth': 4, 'learning_rate': 0.05242265238503059, 'l2_leaf_reg': 1.6787192264806592, 'bagging_temperature': 0.40878273832133694}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:39,280] Trial 187 finished with value: 25750.50690229899 and parameters: {'iterations': 1222, 'depth': 4, 'learning_rate': 0.04417490577690601, 'l2_leaf_reg': 1.3740398350255003, 'bagging_temperature': 0.5253725666499801}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:41,255] Trial 188 finished with value: 25932.74927371586 and parameters: {'iterations': 1168, 'depth': 4, 'learning_rate': 0.03707655376136806, 'l2_leaf_reg': 1.9270821847758464, 'bagging_temperature': 0.46754242698735715}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:43,086] Trial 189 finished with value: 25753.417027168707 and parameters: {'iterations': 1099, 'depth': 4, 'learning_rate': 0.03258672124776871, 'l2_leaf_reg': 1.1799613160056022, 'bagging_temperature': 0.4934851580876949}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:45,482] Trial 190 finished with value: 25585.173979806066 and parameters: {'iterations': 1127, 'depth': 5, 'learning_rate': 0.040239212555937716, 'l2_leaf_reg': 1.0024499683869095, 'bagging_temperature': 0.5655704600064014}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:47,162] Trial 191 finished with value: 26567.83332568481 and parameters: {'iterations': 1071, 'depth': 4, 'learning_rate': 0.12370084258801745, 'l2_leaf_reg': 1.0019151988381838, 'bagging_temperature': 0.4663339376162413}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:48,908] Trial 192 finished with value: 25424.479339102632 and parameters: {'iterations': 1107, 'depth': 4, 'learning_rate': 0.03920493475058012, 'l2_leaf_reg': 1.494819382660937, 'bagging_temperature': 0.4365133402683069}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:50,680] Trial 193 finished with value: 25743.187836881214 and parameters: {'iterations': 1107, 'depth': 4, 'learning_rate': 0.04251577979676518, 'l2_leaf_reg': 1.5001902358362191, 'bagging_temperature': 0.439630056070622}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:52,530] Trial 194 finished with value: 25595.063996781235 and parameters: {'iterations': 1143, 'depth': 4, 'learning_rate': 0.035610422295728354, 'l2_leaf_reg': 1.29807283489026, 'bagging_temperature': 0.3852349140635579}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:54,310] Trial 195 finished with value: 25940.598405189543 and parameters: {'iterations': 1092, 'depth': 4, 'learning_rate': 0.03884983123245099, 'l2_leaf_reg': 1.6177359163866867, 'bagging_temperature': 0.40377777495296663}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:56,292] Trial 196 finished with value: 25815.664450360997 and parameters: {'iterations': 1182, 'depth': 4, 'learning_rate': 0.045595712181609, 'l2_leaf_reg': 1.4536329411971372, 'bagging_temperature': 0.4344791856887114}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:58,059] Trial 197 finished with value: 25660.637019681853 and parameters: {'iterations': 1120, 'depth': 4, 'learning_rate': 0.04983457798102158, 'l2_leaf_reg': 1.2336356706134093, 'bagging_temperature': 0.4508299838386365}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:11:59,878] Trial 198 finished with value: 25532.418532355317 and parameters: {'iterations': 1065, 'depth': 4, 'learning_rate': 0.03444503982774718, 'l2_leaf_reg': 1.7910683731253605, 'bagging_temperature': 0.48288541280604036}. Best is trial 83 with value: 24922.21406237376.
# [I 2025-03-26 16:12:01,805] Trial 199 finished with value: 25402.91421317505 and parameters: {'iterations': 1149, 'depth': 4, 'learning_rate': 0.04125997628072845, 'l2_leaf_reg': 1.1906111050616575, 'bagging_temperature': 0.513135096905437}. Best is trial 83 with value: 24922.21406237376.

# %%
best_params = study.best_params
print("Лучшие гиперпараметры:", best_params)
print("Лучшие значения метрики:", study.best_value)
# Out:
# Лучшие гиперпараметры: {'iterations': 1098, 'depth': 4, 'learning_rate': 0.04000102325817965, 'l2_leaf_reg': 1.0885027090339108, 'bagging_temperature': 0.4668814661901983}
# Лучшие значения метрики: 24922.21406237376

# %% [markdown]
# ## 3. Обучение модели
# Нашли лучшие параметры, обучаем модель

# %%
# параметры, полученные без cross_val_score, переобученные
# optuna_best_params = {
#     'iterations': 761, 
#     'depth': 5, 
#     'learning_rate': 0.0574601909986607, 
#     'l2_leaf_reg': 1.6382426806331774, 
#     'bagging_temperature': 0.6309506369801465
# }

# параметры, получены с cross_val_score
optuna_best_params = {'iterations': 1098, 'depth': 4, 'learning_rate': 0.04000102325817965, 'l2_leaf_reg': 1.0885027090339108, 'bagging_temperature': 0.4668814661901983}

# %%
cat_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', CatBoostRegressor(**optuna_best_params, silent=True))
])

# Обучение модели
cat_pipeline.fit(X_train, y_train)

# Предсказание и оценка
y_pred_cat = cat_pipeline.predict(X_test)
mse_cat = mean_squared_error(y_test, y_pred_cat)
rmse_cat = root_mean_squared_error(y_test, y_pred_cat)
r2_cat = r2_score(y_test, y_pred_cat)

mean_target = np.mean(y_test)

print("\n=== CatBoost ===")
print(f'RMSE: {rmse_cat:.4f}')
print(f'R² (коэффициент детерминации): {r2_cat:.4f}')
print(f'Относительная среднеквадратичная ошибка (Relative RMSE): {rmse_cat/mean_target*100:.2f}%')

# Используем кросс-валидацию (cross-validation), чтобы результаты были надежными и не зависели от случайного разбиения.
scores = cross_val_score(cat_pipeline, X, y, scoring='neg_root_mean_squared_error', cv=5)
rmse_scores = -scores
print("Средний RMSE на кросс-валидации:", rmse_scores.mean())
# Out:
# === CatBoost ===
# RMSE: 23544.0617
# R² (коэффициент детерминации): 0.9206
# Относительная среднеквадратичная ошибка (Relative RMSE): 13.08%
# Средний RMSE на кросс-валидации: 25282.7399368738

# %% [markdown]
# Лучший результат до этого
# - R² (коэффициент детерминации): 0.9224
# - Относительная ошибка (RMSE/mean): 12.93%
# - Средний RMSE на кросс-валидации: 25867.99820262165

# %%
cv = KFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
scores = cross_val_score(cat_pipeline, X, y, scoring='neg_root_mean_squared_error', cv=cv)
rmse_scores = -scores
print("Средний RMSE на стабильной кросс-валидации:", rmse_scores.mean())
# Out:
# Средний RMSE на стабильной кросс-валидации: 27138.466608929688

# %% [markdown]
# ## 4. Формируем Submission файл для Kaggle обучив модель на 100% данных

# %%
cat_pipeline.fit(X, y)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(sparse_threshold=0,
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer())]),
#                                                   Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', '...
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir',
#        'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC',
#        'Fence', 'SaleType', 'SaleCondition'],
#       dtype='object'))])),
#                 ('model',
#                  <catboost.core.CatBoostRegressor object at 0x11a9bdf70>)])

# %%
X_submission = test_data.drop(columns=bad_columns)
X_submission.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley Utilities  \
# 0          20       RH         80.0    11622   Pave   NaN    AllPub
# 1          20       RL         81.0    14267   Pave   NaN    AllPub
# 2          60       RL         74.0    13830   Pave   NaN    AllPub
# 3          60       RL         78.0     9978   Pave   NaN    AllPub
# 4         120       RL         43.0     5005   Pave   NaN    AllPub
#
#   Neighborhood Condition1 Condition2  ... EnclosedPorch 3SsnPorch  \
# 0        NAmes      Feedr       Norm  ...             0         0
# 1        NAmes       Norm       Norm  ...             0         0
# 2      Gilbert       Norm       Norm  ...             0         0
# 3      Gilbert       Norm       Norm  ...             0         0
# 4      StoneBr       Norm       Norm  ...             0         0
#
#    ScreenPorch  PoolArea  PoolQC  Fence MoSold YrSold SaleType SaleCondition
# 0          120         0     NaN  MnPrv      6   2010       WD        Normal
# 1            0         0     NaN    NaN      6   2010       WD        Normal
# 2            0         0     NaN  MnPrv      3   2010       WD        Normal
# 3            0         0     NaN    NaN      6   2010       WD        Normal
# 4          144         0     NaN    NaN      1   2010       WD        Normal
#
# [5 rows x 73 columns]

# %%
y_submission = cat_pipeline.predict(X_submission)
y_submission
# Out:
# array([120080.77010654, 165453.01219465, 189411.67536968, ...,
#        167093.55369236, 123101.27262782, 223647.0150884 ])

# %%
submission = pd.DataFrame({
    'Id': test_data['Id'],
    'SalePrice': y_submission
})
submission.set_index('Id', inplace=True)
submission.head()
# Out:
#           SalePrice
# Id
# 1461  120080.770107
# 1462  165453.012195
# 1463  189411.675370
# 1464  193155.601784
# 1465  186056.390384

# %%
submission.to_csv('submission_optuna_tuned_v3.csv')

# %% [markdown]
# # Выводы
# Гипероптимизация с optuna штука интересная.
# На вход ей лучше подавать (в идеальном мире) - в функцию оценки, не весь дата-сет, а лишь его часть, оставив что-то для финальной валидации модели после подбора параметров.
# В самой функции для оценки лучше использовать не чистый RMSE, а cross_val, чтобы избежать оверфиттинга на одном разбиении данных.
# Но какие бы эксперименты не ставил, никакой из результирующих наборов получавшихся гиперпараметров не смог побить результат самого первого, дефолтного, в лоб взятого набора из итерации improved_realization:
# (iterations=1000,
# learning_rate=0.05,
# depth=6,
# loss_function='RMSE',
# verbose=0,
# random_seed=RANDOM_STATE,
# ), что довольно забавно, учитывая, что в той итерации на подбор гиперпараметров было затрачено примерно 0 минут, а сейчас затрачено несоклько часов экспериментов и улучшений - никаких.
